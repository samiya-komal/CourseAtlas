# %%
import os

# Define the paths to your slave notebooks using raw string literals (r'')
slave_notebook_paths = [
    r'C:\Users\LENOVO\Desktop\UniversityFiles\BrickbecCollegeUniversityOfLondon.ipynb',
    r'C:\Users\LENOVO\Desktop\UniversityFiles\UniversityOfAngelia.ipynb',
    r'C:\Users\LENOVO\Desktop\UniversityFiles\UniversityOfBradford.ipynb',
    r'C:\Users\LENOVO\Desktop\UniversityFiles\UniversityOfPortsmouth.ipynb',
    r'C:\Users\LENOVO\Desktop\UniversityFiles\UniversityOfSouthhampton.ipynb',
    r'C:\Users\LENOVO\Desktop\UniversityFiles\AstonUniversity.ipynb',
    r'C:\Users\LENOVO\Desktop\UniversityFiles\BrunelUniversityLondon.ipynb'
]

# Loop through each slave notebook and execute it using nbconvert
for notebook_path in slave_notebook_paths:
    os.system(f'jupyter nbconvert --to notebook --execute {notebook_path}')
